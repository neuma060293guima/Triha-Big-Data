# %%
#Lembre-se: noterminal, rodar 'pip instal matpotlib
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
amostra=[random.randint(1,99) for i in range(20)]
dados=np.array(amostra)
print(dados)
# Out:
# [89 56 61 99 53 41 72 79 28  6  9 27 84 37 53 54 59  2 17 13]

# %%
q1=np.percentile(dados,25)
q2=np.percentile(dados,50)
q3=np.percentile(dados,75)

#Exibição:
print(f'Primeiro Quartil (Q1:{q1})')
print(f'Segundo Quartil (Q2:{q2})')
print(f'Terceiro Quartil (Q3:{q3})')
# Out:
# Primeiro Quartil (Q1:24.5)
# Segundo Quartil (Q2:53.0)
# Terceiro Quartil (Q3:63.75)

# %% [markdown]
# Atividade em Aula:Calcule os Quartisdo dataset nutricional trabalhamdo na aula anterior, exibindo em seguida.
#
# Gráficos-Biblioteca MatPlotLib

# %%
plt.figure(figsize=(10,6))
plt.bar(range(1,21),dados,color='purple')
plt.xlabel('Índices')
plt.ylabel('Valores Aleatórios')
plt.title('Gráfico de Barras de Mais de 20 números Aleatórios')
plt.xticks(range(1,21))
# Out:
# ([<matplotlib.axis.XTick at 0x21481f74310>,
# ...
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12'),
#   Text(13, 0, '13'),
#   Text(14, 0, '14'),
#   Text(15, 0, '15'),
#   Text(16, 0, '16'),
#   Text(17, 0, '17'),
#   Text(18, 0, '18'),
#   Text(19, 0, '19'),
#   Text(20, 0, '20')])
